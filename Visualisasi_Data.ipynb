# %% [markdown]
# <a href="https://colab.research.google.com/github/lsawfa/Data-Visualization/blob/main/Visualisasi_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# admin Larynt Sawfa Kenanga
# VISUALISASI VARIABEL 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

# load in dataframe and select a portion
df = pd.read_csv('Regresi.csv')

# convert height and weight columns to lists
x_list = df['x'].tolist()
y_list = df['y'].tolist()

# convert lists to numpy lists
xs = np.array(x_list, dtype=np.float64)
ys = np.array(y_list, dtype=np.float64)

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
plt.title('Aspect E-wallet and effect regression')
plt.xlabel('Aspect E-wallet')
plt.ylabel('effect regression')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# VISUALISASI VARIABEL PENGELUARAN DAN PEMASUKAN PER BULAN DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS KORELASI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
pengeluaran_list = df['Pengeluaran per Bulan'].tolist()
pemasukan_list = df['Pemasukan per Bulan'].tolist()

# convert lists to numpy lists
xs = np.array(pengeluaran_list, dtype=np.float64)
ys = np.array(pemasukan_list, dtype=np.float64)

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
plt.title('Pengeluaran dan pemasukan linear regression')
plt.xlabel('Pengeluaran (juta rupiah/bulan)')
plt.ylabel('Pemasukan (juta rupiah/bulan)')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# VISUALISASI VARIABEL PENGELUARAN DAN PEMASUKAN PER BULAN DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS REGRESI LINEAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
pengeluaran_list = df['Pengeluaran per Bulan'].tolist()
pemasukan_list = df['Pemasukan per Bulan'].tolist()

# convert lists to numpy lists
xs = np.array(pengeluaran_list, dtype=np.float64)
ys = np.array(pemasukan_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_pengeluaran = 1924879.31
average_pemasukan = (slope * average_pengeluaran) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
plt.scatter(average_pengeluaran,average_pemasukan, label='average prediction',color='red', s=116)
plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=4)
plt.title('Pengeluaran dan pemasukan linear regression')
plt.xlabel('Pengeluaran (juta rupiah/bulan)')
plt.ylabel('Pemasukan (juta rupiah/bulan)')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 1 dan 2
# VISUALISASI VARIABEL Pengaturan Keuangan DAN Kontent informasi E-Wallet DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS KORELASI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i1_list = df['Pengaturan keuangan'].tolist()
i2_list = df['Konten informasi E-Wallet'].tolist()

# convert lists to numpy lists
xs = np.array(i1_list, dtype=np.float64)
ys = np.array(i2_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i1 = 3.232758621
average_i2 = (slope * average_i1) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
# plt.scatter(average_pengeluaran,average_pemasukan, label='average prediction',color='red', s=116)
# plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Pengaturan Keuangan dan Kontent informasi E-Wallet linear regression')
plt.xlabel('Pengaturan Keuangan)')
plt.ylabel('Kontent informasi E-Wallet')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 1 dan 2
# VISUALISASI VARIABEL Pengaturan Keuangan DAN Kontent informasi E-Wallet DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS REGRESI LINEAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i1_list = df['Pengaturan keuangan'].tolist()
i2_list = df['Konten informasi E-Wallet'].tolist()

# convert lists to numpy lists
xs = np.array(i1_list, dtype=np.float64)
ys = np.array(i2_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i1 = 3.232758621
average_i2 = (slope * average_i1) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
# plt.scatter(average_pengeluaran,average_pemasukan, label='average prediction',color='red', s=116)
plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Pengaturan Keuangan dan Kontent informasi E-Wallet linear regression')
plt.xlabel('Pengaturan Keuangan)')
plt.ylabel('Kontent informasi E-Wallet')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 3 dan 4
# VISUALISASI VARIABEL Instrumen pemborosan E-Wallet dan tingkat kekonsumtifan  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS KORELASI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i3_list = df['Instrumen pemborosan E-Wallet'].tolist()
i4_list = df['Tingkat konsumtifan'].tolist()

# convert lists to numpy lists
xs = np.array(i3_list, dtype=np.float64)
ys = np.array(i4_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i3 = 3.293103
average_i4 = (slope * average_i3) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
# plt.scatter(average_i3, average_i4, label='average prediction',color='red', s=116)
# plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Instrumen pemborosan E-Wallet dan Tingkat konsumtifan linear regression')
plt.xlabel('Instrumen pemborosan E-Wallet)')
plt.ylabel('Tingkat konsumtifan')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 3 dan 4
# Visualisasi variabel Instrumen pemborosan E-Wallet dan tingkat kekonsumtifan menggunakan scatter plot  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS REGRESI LINEAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i3_list = df['Instrumen pemborosan E-Wallet'].tolist()
i4_list = df['Tingkat konsumtifan'].tolist()

# convert lists to numpy lists
xs = np.array(i3_list, dtype=np.float64)
ys = np.array(i4_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i3 = 3.293103
average_i4 = (slope * average_i3) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
plt.scatter(average_i3, average_i4, label='average prediction',color='red', s=116)
plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Instrumen pemborosan E-Wallet dan Tingkat konsumtifan linear regression')
plt.xlabel('Instrumen pemborosan E-Wallet)')
plt.ylabel('Tingkat konsumtifan')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 5 dan 6
# Visualisasi variabel Instrumen Kembalian E-Wallet dan Kepraktisan Top up E-Wallet menggunakan scatter plot  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS REGRESI LINEAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i5_list = df['Instrumen Kembalian E-Wallet'].tolist()
i6_list = df['Kepraktisan Top up E-Wallet'].tolist()

# convert lists to numpy lists
xs = np.array(i5_list, dtype=np.float64)
ys = np.array(i6_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i5 = 3.155172
average_i6 = (slope * average_i5) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
# plt.scatter(average_i5, average_i6, label='average prediction',color='red', s=116)
# plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Instrumen pemborosan E-Wallet dan Tingkat konsumtifan linear regression')
plt.xlabel('Instrumen pemborosan E-Wallet)')
plt.ylabel('Tingkat konsumtifan')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 5 dan 6
# Visualisasi variabel Instrumen Kembalian E-Wallet dan Kepraktisan Top up E-Wallet menggunakan scatter plot  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS REGRESI LINEAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i5_list = df['Instrumen Kembalian E-Wallet'].tolist()
i6_list = df['Kepraktisan Top up E-Wallet'].tolist()

# convert lists to numpy lists
xs = np.array(i5_list, dtype=np.float64)
ys = np.array(i6_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i5 = 3.155172
average_i6 = (slope * average_i5) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
plt.scatter(average_i5, average_i6, label='average prediction',color='red', s=116)
plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Instrumen pemborosan E-Wallet dan Tingkat konsumtifan linear regression')
plt.xlabel('Instrumen pemborosan E-Wallet)')
plt.ylabel('Tingkat konsumtifan')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 7 dan 8
# Visualisasi variabel Kemudahan Penggunaan dan Aksebilitas bandwitch E-Wallet menggunakan scatter plot  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS KORELASI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i7_list = df['Kemudahan Penggunaan'].tolist()
i8_list = df['Aksebilitas bandwitch E-Wallet'].tolist()

# convert lists to numpy lists
xs = np.array(i7_list, dtype=np.float64)
ys = np.array(i8_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i7 = 4.034483
average_i8 = (slope * average_i5) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
# plt.scatter(average_i7, average_i8, label='average prediction',color='red', s=116)
# plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Kemudahan Penggunaan dan Aksebilitas bandwitch E-Wallet linear regression')
plt.xlabel('Kemudahan Penggunaan')
plt.ylabel('Aksebilitas bandwitch E-Wallet')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 7 dan 8
# Visualisasi variabel Kemudahan Penggunaan dan Aksebilitas bandwitch E-Wallet menggunakan scatter plot  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS REGRESI LIENAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i7_list = df['Kemudahan Penggunaan'].tolist()
i8_list = df['Aksebilitas bandwitch E-Wallet'].tolist()

# convert lists to numpy lists
xs = np.array(i7_list, dtype=np.float64)
ys = np.array(i8_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i7 = 4.034483
average_i8 = (slope * average_i7) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
plt.scatter(average_i7, average_i8, label='average prediction',color='red', s=116)
plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Kemudahan Penggunaan dan Aksebilitas bandwitch E-Wallet linear regression')
plt.xlabel('Kemudahan Penggunaan')
plt.ylabel('Aksebilitas bandwitch E-Wallet')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 9 dan 10
# Visualisasi variabel Pengganti uang tunai dan E-Wallet transaction in Merchant menggunakan scatter plot  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS KORELASI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i9_list = df['Pengganti uang tunai'].tolist()
i10_list = df['E-Wallet transaction in Merchant'].tolist()

# convert lists to numpy lists
xs = np.array(i9_list, dtype=np.float64)
ys = np.array(i10_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i9 = 3.603448
average_i10 = (slope * average_i9) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
# plt.scatter(average_i9, average_i10, label='average prediction',color='red', s=116)
# plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Pengganti uang tunai dan E-Wallet transaction in Merchant linear regression')
plt.xlabel('Pengganti uang tunai')
plt.ylabel('E-Wallet transaction in Merchant')
plt.legend()
plt.show()

# %%
# admin Larynt Sawfa Kenanga
# 9 dan 10
# Visualisasi variabel Pengganti uang tunai dan E-Wallet transaction in Merchant menggunakan scatter plot  DENGAN MENGGUNAKAN SCATTER PLOT DAN ANALISIS REGRESI LINEAR
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from statistics import mean
from sklearn import linear_model

def best_fit_line(xs,ys):
    slope = (((mean(xs) * mean(ys)) - mean(xs * ys)) / ((mean(xs) * mean(xs)) - mean(xs * xs)))
    y_intercept = mean(ys) - slope * mean(xs)
    return slope, y_intercept

# load in dataframe and select a portion
df = pd.read_csv('Rekapitulasi of Kuisioner E-Wallet.csv')

# convert height and weight columns to lists
i9_list = df['Pengganti uang tunai'].tolist()
i10_list = df['E-Wallet transaction in Merchant'].tolist()

# convert lists to numpy lists
xs = np.array(i9_list, dtype=np.float64)
ys = np.array(i10_list, dtype=np.float64)

# 1st method: using our own function
# calculated slope and y-intercept of the lists
slope, y_intercept = best_fit_line(xs,ys)

# get the regression line from the calculated slope and y-intercept
regression_line = [(slope * x) + y_intercept for x in xs]

# Making predictions
average_i9 = 3.603448
average_i10 = (slope * average_i9) + y_intercept

# Plot outputs and plot customization
style.use('seaborn')
plt.scatter(xs,ys,label='Data Points', alpha=0.6,color='green',s=116)
plt.scatter(average_i9, average_i10, label='average prediction',color='red', s=116)
plt.plot(xs,regression_line,label='Best Fit Line', color='orange',linewidth=5)
plt.title('Pengganti uang tunai dan E-Wallet transaction in Merchant linear regression')
plt.xlabel('Pengganti uang tunai')
plt.ylabel('E-Wallet transaction in Merchant')
plt.legend()
plt.show()
